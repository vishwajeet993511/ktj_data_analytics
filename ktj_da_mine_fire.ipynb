# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
pd.read_csv?

# %%
dx = pd.read_table("doc_mine.txt",delimiter= " ")
dmine = pd.read_table("doc2_mine.txt",delimiter= " ")

# %%
dx.head()
# Out:
#    Year  U/Gworking  Surfaceworking  O/Cworking
# 0  1980          18               4           0
# 1  1981           8               3           1
# 2  1982           8               1           2
# 3  1983          19               5           2
# 4  1984          13               1           2

# %%
dmine.head()
# Out:
#    Year  Fatal_accident_rate_per_1000_persons_employed    v1    v2    v3  \
# 0  1990                                           0.27  0.33  0.42  0.20
# 1  1991                                           0.25  0.26  0.39  0.20
# 2  1992                                           0.30  0.39  0.52  0.16
# 3  1993                                           0.29  0.39  0.37  0.19
# 4  1994                                           0.30  0.59  0.64  0.15
#
#      v4  Serious_accident_rate  per_1000_persons_employed    v5    v6  Overall
# 0  0.30                   1.63                       2.38  1.16  0.96     1.79
# 1  0.26                   1.45                       1.96  1.00  0.98     1.54
# 2  0.33                   1.46                       2.14  0.79  1.01     1.62
# 3  0.32                   1.56                       2.19  0.83  1.01     1.65
# 4  0.46                   1.37                       2.08  0.86  0.67     1.48

# %%
dmine.shape
# Out:
# (25, 11)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
plt.plot(dmine.Year,dmine.Overall)
plt.xlabel("Year in which accidents occured")
plt.ylabel("Fatal accident rate per 1000 persons employed")
plt.show()

# %%
#plt.hist(dx.Year,dx.Surfaceworking)

# %%
#dx.set_index('Year', inplace=True)

# %%
plt.figure()
plt.bar?

# %%
import matplotlib.patches as mpatches
plt.bar(dx.Year,dx.Surfaceworking)
plt.bar(dx.Year,dx["U/Gworking"],bottom=dx.Surfaceworking)
red_patch = mpatches.Patch(color='orange', label='U/G working')
blue_patch = mpatches.Patch(color='blue', label='Surface working')
plt.legend(handles=[red_patch,blue_patch])
plt.xlabel("Year in which accidents occured")
plt.ylabel("number of accidents Working in coal mines ")
plt.show()

# %%
dx
# Out:
#       U/Gworking  Surfaceworking  O/Cworking
# Year
# 1980          18               4           0
# 1981           8               3           1
# 1982           8               1           2
# 1983          19               5           2
# 1984          13               1           2
# 1985          19               1           3
# 1986          19               1           2
# 1987          19               0           2
# 1988          12               0           1
# 1989           9               3           2
# 1990          14               5           0
# 1991          11              10           2
# 1992          14              22           0
# 1993           9              11           3
# 1994           5              22           6
# 1995          10              26           2
# 1996          12              10           3
# 1997           8              19           7
# 1998          10               9           2
# 1999          10              14           4
# ...
